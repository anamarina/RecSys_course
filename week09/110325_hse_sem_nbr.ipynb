# %%
import pandas as pd
import numpy as np

# %% [markdown]
# скачайте датасет
# https://www.kaggle.com/datasets/chiranjivdas09/ta-feng-grocery-dataset

# %%
# !unzip ../../archive.zip
# Out:
# Archive:  ../../archive.zip
#   inflating: ta_feng_all_months_merged.csv

# %%
df = pd.read_csv('ta_feng_all_months_merged.csv')
df['TRANSACTION_DT'] = pd.to_datetime(df['TRANSACTION_DT'])
df = df.sort_values(by='TRANSACTION_DT')
df.head()
# Out:
#     TRANSACTION_DT  CUSTOMER_ID AGE_GROUP PIN_CODE  PRODUCT_SUBCLASS  \
# 0       2000-11-01      1104905     45-49      115            110411
# 907     2000-11-01      2015071     35-39      221            500509
# 906     2000-11-01      2090375       NaN  Unknown            110411
# 905     2000-11-01       166324     60-64      115            100505
# 904     2000-11-01      2015071     35-39      221            110404
#
#         PRODUCT_ID  AMOUNT  ASSET  SALES_PRICE
# 0    4710199010372       2     24           30
# 907       20515461       1     18           24
# 906  4710110241014       1     31           38
# 905  4710154015206       1     32           37
# 904  4710175566374       1     88          122

# %%
df.rename({'CUSTOMER_ID':'user_id','PRODUCT_ID':'item_id','TRANSACTION_DT':'timestamp'}, axis=1, inplace=True)
df.head()
# Out:
#      timestamp  user_id AGE_GROUP PIN_CODE  PRODUCT_SUBCLASS        item_id  \
# 0   2000-11-01  1104905     45-49      115            110411  4710199010372
# 907 2000-11-01  2015071     35-39      221            500509       20515461
# 906 2000-11-01  2090375       NaN  Unknown            110411  4710110241014
# 905 2000-11-01   166324     60-64      115            100505  4710154015206
# 904 2000-11-01  2015071     35-39      221            110404  4710175566374
#
#      AMOUNT  ASSET  SALES_PRICE
# 0         2     24           30
# 907       1     18           24
# 906       1     31           38
# 905       1     32           37
# 904       1     88          122

# %% [markdown]
# # посчитайте, сколько раз поторов покупок

# %%
# your code here

df[['user_id','item_id']].value_counts()[:30]
# Out:
# user_id  item_id
# 2019604  4710088433305    49
# 1113952  4710085120161    44
# 2019604  4710088433312    40
# 1657982  4710088433312    38
# 2019604  4710088434104    37
#          4710105051321    28
# 1991741  4710088433312    26
# 2000558  4710058278059    25
# 1075274  4710094097768    24
# 1657982  4710088432476    23
# 1136791  4711080010112    22
# 991407   4710105015118    21
# 1657982  4710105051642    21
# 920308   4711022100017    20
# 1846904  4714981010038    20
# 1769081  4710126184268    18
# 309448   4710046011101    18
# 950565   4710105010144    17
# 1638080  4710105015118    17
# 1573879  4972045758337    17
# 906456   20415723         17
# 49122    4710105010649    17
# 616195   4710339000010    16
# 882682   4710110222228    16
# 427159   4711080010112    16
# 882682   4710110222235    16
# 2068718  4710085104130    16
# 1098143  4710421090059    15
# 2154978  80135906         15
# 2032207  4711080010112    15
# Name: count, dtype: int64

# %% [markdown]
# ## Давайте создадим leave-one-out basket

# %%
df['basket_id'] = df.groupby('user_id')['timestamp'].rank(method='dense', ascending=False)

df.loc[df.user_id==1637335][['user_id','item_id','timestamp','basket_id']]
# Out:
#         user_id        item_id  timestamp  basket_id
# 6751    1637335  4712815116246 2000-11-02        6.0
# 6793    1637335  4710094001758 2000-11-02        6.0
# 6773    1637335  4711258001256 2000-11-02        6.0
# 5948    1637335  4710049000386 2000-11-02        6.0
# 5931    1637335  4901422038939 2000-11-02        6.0
# 9188    1637335  4710094021572 2000-11-02        6.0
# 7815    1637335    50000301829 2000-11-02        6.0
# 7723    1637335  4710363431002 2000-11-02        6.0
# 7951    1637335  4901872810543 2000-11-02        6.0
# 7539    1637335  4710101203144 2000-11-02        6.0
# 7529    1637335  4710363604000 2000-11-02        6.0
# 7514    1637335  4710363911610 2000-11-02        6.0
# 81995   1637335  4710038783221 2000-11-11        5.0
# 79310   1637335  9300644131711 2000-11-11        5.0
# 80972   1637335  4710168152225 2000-11-11        5.0
# 82803   1637335  4714981010038 2000-11-11        5.0
# 82382   1637335    37000802068 2000-11-11        5.0
# 108098  1637335  5000174957778 2000-11-14        4.0
# 108100  1637335  5000174958164 2000-11-14        4.0
# 108784  1637335  4710049000386 2000-11-14        4.0
# 112503  1637335  4710043552102 2000-11-14        4.0
# 113640  1637335  4710032701085 2000-11-14        4.0
# 112010  1637335  8850006267073 2000-11-14        4.0
# 432376  1637335       20072322 2001-01-11        3.0
# 455143  1637335  4710329120230 2001-01-11        3.0
# 435145  1637335  4710049000386 2001-01-11        3.0
# 434342  1637335       20522650 2001-01-11        3.0
# 435566  1637335  4712815113269 2001-01-11        3.0
# 407589  1637335  4710036003581 2001-01-14        2.0
# 410777  1637335  4710046011156 2001-01-14        2.0
# 411477  1637335  4710084225829 2001-01-14        2.0
# 409903  1637335  4710431302760 2001-01-14        2.0
# 431791  1637335  4713089003102 2001-01-14        2.0
# 718632  1637335  4710168705056 2001-02-15        1.0
# 720876  1637335  4710363158374 2001-02-15        1.0
# 720474  1637335  4712815116246 2001-02-15        1.0
# 716002  1637335  4901422038939 2001-02-15        1.0

# %% [markdown]
# ## Закодируйте айтемы к 0, ..., n_items

# %%
df.head()
# 0 ... n_users
# 0 ... n_items
# Out:
#      timestamp  user_id AGE_GROUP PIN_CODE  PRODUCT_SUBCLASS        item_id  \
# 0   2000-11-01  1104905     45-49      115            110411  4710199010372
# 907 2000-11-01  2015071     35-39      221            500509       20515461
# 906 2000-11-01  2090375       NaN  Unknown            110411  4710110241014
# 905 2000-11-01   166324     60-64      115            100505  4710154015206
# 904 2000-11-01  2015071     35-39      221            110404  4710175566374
#
#      AMOUNT  ASSET  SALES_PRICE  basket_id
# 0         2     24           30       13.0
# 907       1     18           24        9.0
# 906       1     31           38       24.0
# 905       1     32           37       17.0
# 904       1     88          122        9.0

# %%
user2id = {x: idx for idx, x in enumerate(df.user_id.unique())}
item2id = {x: idx for idx, x in enumerate(df.item_id.unique())}

df['user_id'] = df['user_id'].apply(lambda x: user2id[x])
df['item_id'] = df['item_id'].apply(lambda x: item2id[x])

# %%
df.head()
# Out:
#      timestamp  user_id AGE_GROUP PIN_CODE  PRODUCT_SUBCLASS  item_id  AMOUNT  \
# 0   2000-11-01        0     45-49      115            110411        0       2
# 907 2000-11-01        1     35-39      221            500509        1       1
# 906 2000-11-01        2       NaN  Unknown            110411        2       1
# 905 2000-11-01        3     60-64      115            100505        3       1
# 904 2000-11-01        1     35-39      221            110404        4       1
#
#      ASSET  SALES_PRICE  basket_id
# 0       24           30       13.0
# 907     18           24        9.0
# 906     31           38       24.0
# 905     32           37       17.0
# 904     88          122        9.0

# %%
test_baskets = df.loc[df.basket_id==1].copy()
train_baskets = df.loc[df.basket_id!=1].copy()

train_baskets.head()
# Out:
#      timestamp  user_id AGE_GROUP PIN_CODE  PRODUCT_SUBCLASS  item_id  AMOUNT  \
# 0   2000-11-01        0     45-49      115            110411        0       2
# 907 2000-11-01        1     35-39      221            500509        1       1
# 906 2000-11-01        2       NaN  Unknown            110411        2       1
# 905 2000-11-01        3     60-64      115            100505        3       1
# 904 2000-11-01        1     35-39      221            110404        4       1
#
#      ASSET  SALES_PRICE  basket_id
# 0       24           30       13.0
# 907     18           24        9.0
# 906     31           38       24.0
# 905     32           37       17.0
# 904     88          122        9.0

# %%
train_grouped = train_baskets.groupby('user_id').apply(lambda x: list(zip(x.basket_id, x.item_id))).reset_index()
train_grouped.rename({0: 'train_baskets'}, axis=1, inplace=True)

test_grouped = test_baskets.groupby('user_id').apply(lambda x: list(zip(x.basket_id, x.item_id))).reset_index()
test_grouped.rename({0: 'test_baskets'}, axis=1, inplace=True)

# %%
train_grouped.head()
# Out:
#    user_id                                      train_baskets
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...

# %%
test_grouped.head()
# Out:
#    user_id                                       test_baskets
# 0        0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1        1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2        2                                      [(1.0, 1603)]
# 3        3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4        4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...

# %%
grouped = train_grouped.merge(test_grouped)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...

# %% [markdown]
# будем делать рекомендации на 20 элементах

# %%
k = 20

# %% [markdown]
# реализуйте 20 рандомный рекомендаций

# %%
random_recs = np.random.choice(np.arange(len(item2id)), size=k)# your code here

# %%
random_recs[None,:]
# Out:
# array([[ 5159, 17112, 21847, 21220, 13090,   256, 13625,  2834, 15642,
#          4489, 20709,  6129, 22151,   699, 11549, 14232, 22628,  5229,
#         18975, 15617]])

# %%
grouped['random_recs'] = grouped.user_id.apply(lambda x: random_recs)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets  \
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...
#
#                                          random_recs
# 0  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 1  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 2  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 3  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 4  [5159, 17112, 21847, 21220, 13090, 256, 13625,...

# %%
def ndcg_metric(gt_items, predicted):
    
    at = len(predicted)
    relevance = np.array([1 if x in predicted else 0 for x in gt_items])
    # DCG uses the relevance of the recommended items
    rank_dcg = dcg(relevance)

    if rank_dcg == 0.0:
        return 0.0

    # IDCG has all relevances to 1 (or the values provided), up to the number of items in the test set that can fit in the list length
    ideal_dcg = dcg(np.sort(relevance)[::-1][:at])

    if ideal_dcg == 0.0:
        return 0.0

    ndcg_ = rank_dcg / ideal_dcg

    return ndcg_


def dcg(scores):
    return np.sum(np.divide(np.power(2, scores) - 1, np.log2(np.arange(scores.shape[0], dtype=np.float64) + 2)),
                  dtype=np.float64)


def recall_metric(gt_items, predicted):
    
    n_gt = len(gt_items)
    intersection = len(set(gt_items).intersection(set(predicted)))
    return intersection / n_gt

def evaluate_recommender(df, model_preds, gt_col='test_interactions', topn=10):
    
    metric_values = []
    
    for idx, row in df.iterrows():
        gt_items = [x[1] for x in row[gt_col]]
        metric_values.append((ndcg_metric(gt_items, row[model_preds]),
                              recall_metric(gt_items, row[model_preds])))
        
    return {'ndcg':np.mean([x[0] for x in metric_values]),
            'recall':np.mean([x[1] for x in metric_values])}

# %%
evaluate_recommender(grouped, gt_col='test_baskets', model_preds='random_recs', topn=k)
# Out:
# {'ndcg': 0.001742533804137601, 'recall': 0.00046218883964167876}

# %%
len(item2id)
# Out:
# 23812

# %% [markdown]
# ## Теперь можем строить рекомендации

# %% [markdown]
# ### Постройте рекомендации по популярности по количеству покупок и оцените качество

# %%
train_baskets.item_id.value_counts()[:30]
# Out:
# item_id
# 13       5494
# 6        4614
# 13700    1809
# 57       1712
# 3639     1570
# 509      1508
# 290      1372
# 1761     1368
# 9        1289
# 62       1287
# 407      1284
# 1302     1278
# 60       1202
# 956      1187
# 173      1164
# 69       1163
# 50       1080
# 1956     1008
# 14        988
# 4914      932
# 3543      903
# 1368      902
# 1455      900
# 1763      879
# 1345      818
# 154       812
# 283       806
# 2282      790
# 55        789
# 2358      785
# Name: count, dtype: int64

# %%
most_pop = train_baskets.item_id.value_counts().index.tolist()[:k] # your code here
most_pop
# Out:
# [13,
#  6,
#  13700,
#  57,
#  3639,
#  509,
#  290,
#  1761,
#  9,
#  62,
#  407,
#  1302,
#  60,
#  956,
#  173,
#  69,
#  50,
#  1956,
#  14,
#  4914]

# %%
grouped['mostpoprecs'] = grouped.user_id.apply(lambda x: most_pop)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets  \
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...
#
#                                          random_recs  \
# 0  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 1  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 2  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 3  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 4  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
#
#                                          mostpoprecs
# 0  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 1  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 2  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 3  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 4  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='mostpoprecs', topn=k)
# Out:
# {'ndcg': 0.1902223218557026, 'recall': 0.0969647255458864}

# %% [markdown]
# ## теперь посчитайте популярность по клиентам

# %%
mostpop2 = train_baskets.drop_duplicates(subset=['user_id','item_id']).item_id.value_counts().index.tolist()[:k]
mostpop2
# Out:
# [6,
#  13,
#  13700,
#  3639,
#  1761,
#  509,
#  407,
#  57,
#  1302,
#  290,
#  9,
#  956,
#  60,
#  50,
#  62,
#  69,
#  14,
#  173,
#  1368,
#  3543]

# %%
most_pop
# Out:
# [13,
#  6,
#  13700,
#  57,
#  3639,
#  509,
#  290,
#  1761,
#  9,
#  62,
#  407,
#  1302,
#  60,
#  956,
#  173,
#  69,
#  50,
#  1956,
#  14,
#  4914]

# %%
grouped['mostpoprecs2'] = grouped.user_id.apply(lambda x: mostpop2)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets  \
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...
#
#                                          random_recs  \
# 0  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 1  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 2  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 3  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 4  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
#
#                                          mostpoprecs  \
# 0  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 1  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 2  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 3  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 4  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
#
#                                         mostpoprecs2
# 0  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 1  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 2  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 3  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 4  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='mostpoprecs2', topn=k)
# Out:
# {'ndcg': 0.19671364391441537, 'recall': 0.10134244721016634}

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='mostpoprecs', topn=k)
# Out:
# {'ndcg': 0.1902223218557026, 'recall': 0.0969647255458864}

# %% [markdown]
# ## Сравните рекомендации между двумя видами популярности

# %%
# your code here

# %%
test_baskets.timestamp.value_counts()[:30]
# Out:
# timestamp
# 2001-02-25    11673
# 2001-02-28     9375
# 2001-02-24     8183
# 2001-01-21     7634
# 2001-01-22     6833
# 2001-02-11     6625
# 2001-02-18     6348
# 2001-02-10     5424
# 2001-02-04     5313
# 2001-02-17     4811
# 2001-02-23     4553
# 2001-02-03     4444
# 2001-02-27     4432
# 2001-02-21     4367
# 2001-01-14     4313
# 2001-02-22     4156
# 2001-02-26     4154
# 2001-02-19     4140
# 2001-01-20     3984
# 2001-02-20     3640
# 2000-12-17     3467
# 2001-02-15     3398
# 2000-12-31     3042
# 2001-02-16     3020
# 2001-01-01     3020
# 2001-02-14     3010
# 2001-01-23     2897
# 2001-01-13     2867
# 2001-01-18     2816
# 2001-01-19     2669
# Name: count, dtype: int64

# %% [markdown]
# ## Давайте сделаем рекомендации по персональной популярности

# %%
def count_personal_recs(row):
    
    # your code here
    counts = {}
    for l in row.train_baskets:
        
        item = l[1]
        if item in counts:
            counts[item] += 1
        else:
            counts[item] = 1
            
    counts = list(sorted(counts.items(), key=lambda x: -x[1]))
    
    items = [x[0] for x in counts] 
    
    
    return items[:k]


grouped['user_popular'] = grouped.apply(lambda x: count_personal_recs(x), axis=1)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets  \
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...
#
#                                          random_recs  \
# 0  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 1  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 2  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 3  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 4  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
#
#                                          mostpoprecs  \
# 0  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 1  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 2  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 3  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 4  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
#
#                                         mostpoprecs2  \
# 0  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 1  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 2  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 3  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 4  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
#
#                                         user_popular
# 0  [453, 60, 15042, 1060, 1956, 12913, 83, 8615, ...
# 1  [3620, 400, 13, 4624, 1405, 1, 4, 17, 25, 26, ...
# 2  [2396, 3710, 8, 306, 6009, 611, 1653, 8031, 13...
# 3  [55, 6, 3, 7, 11, 13, 24, 27, 29, 31, 39, 40, ...
# 4  [792, 282, 790, 2309, 5871, 1883, 7750, 58, 68...

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='user_popular', topn=k)
# Out:
# {'ndcg': 0.23166610618797306, 'recall': 0.11365481405632985}

# %%
{'ndcg': 0.19671364391441537, 'recall': 0.10134244721016634}
# Out:
# {'ndcg': 0.19671364391441537, 'recall': 0.10134244721016634}

# %% [markdown]
# ## Реализуем эвристику TopPersonal s(u, i) = a * f(u, i, t) + (1-a) * p(i)

# %%
# s = sorted(scores, lambda x: (freq, popularity))

# (batch, num_items)
# freq + popularity 
# popularity > 1 -> (0, 1)

popularity = train_baskets.drop_duplicates(subset=['user_id','item_id']).item_id.value_counts().reset_index()
popularity['count'] /= popularity['count'].max()
populartiy = {k: v for k, v in zip(popularity.item_id, popularity['count'])}

# %%
def count_personal_recs(row):
    
    # your code here
    counts = {}
    for l in row.train_baskets:
        
        item = l[1]
        if item in counts:
            counts[item] += 1
        else:
            counts[item] = 1
            
    for t in counts:
        counts[t] += popularity.get(t, 0)
     
    counts = list(sorted(counts.items(), key=lambda x: -x[1]))
    
    
    items = [x[0] for x in counts][:k] 
    items = items + [x for x in mostpop2 if x not in items]
    
    return items[:k]


grouped['toppersonal'] = grouped.apply(lambda x: count_personal_recs(x), axis=1)
grouped.head()
# Out:
#    user_id                                      train_baskets  \
# 0        0  [(13.0, 0), (13.0, 453), (13.0, 223), (13.0, 5...
# 1        1  [(9.0, 1), (9.0, 4), (9.0, 17), (9.0, 25), (9....
# 2        2  [(24.0, 2), (24.0, 8), (24.0, 15), (24.0, 20),...
# 3        3  [(17.0, 3), (17.0, 7), (17.0, 11), (17.0, 13),...
# 4        4  [(33.0, 5), (33.0, 30), (33.0, 46), (33.0, 58)...
#
#                                         test_baskets  \
# 0  [(1.0, 60), (1.0, 3152), (1.0, 267), (1.0, 861...
# 1  [(1.0, 216), (1.0, 5029), (1.0, 865), (1.0, 23...
# 2                                      [(1.0, 1603)]
# 3  [(1.0, 3012), (1.0, 13), (1.0, 883), (1.0, 3712)]
# 4  [(1.0, 1011), (1.0, 6347), (1.0, 282), (1.0, 9...
#
#                                          random_recs  \
# 0  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 1  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 2  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 3  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
# 4  [5159, 17112, 21847, 21220, 13090, 256, 13625,...
#
#                                          mostpoprecs  \
# 0  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 1  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 2  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 3  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
# 4  [13, 6, 13700, 57, 3639, 509, 290, 1761, 9, 62...
#
#                                         mostpoprecs2  \
# 0  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 1  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 2  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 3  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
# 4  [6, 13, 13700, 3639, 1761, 509, 407, 57, 1302,...
#
#                                         user_popular  \
# 0  [453, 60, 15042, 1060, 1956, 12913, 83, 8615, ...
# 1  [3620, 400, 13, 4624, 1405, 1, 4, 17, 25, 26, ...
# 2  [2396, 3710, 8, 306, 6009, 611, 1653, 8031, 13...
# 3  [55, 6, 3, 7, 11, 13, 24, 27, 29, 31, 39, 40, ...
# 4  [792, 282, 790, 2309, 5871, 1883, 7750, 58, 68...
#
#                                          toppersonal
# 0  [453, 60, 15042, 1060, 1956, 12913, 83, 8615, ...
# 1  [3620, 400, 13, 4624, 1405, 1, 4, 17, 25, 26, ...
# 2  [2396, 3710, 8, 306, 6009, 611, 1653, 8031, 13...
# 3  [55, 6, 3, 7, 11, 13, 24, 27, 29, 31, 39, 40, ...
# 4  [792, 282, 790, 2309, 5871, 1883, 7750, 58, 68...

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='toppersonal', topn=k)
# Out:
# {'ndcg': 0.29006386845146764, 'recall': 0.1524134873788588}

# %%
evaluate_recommender(grouped, gt_col='test_baskets',model_preds='mostpoprecs', topn=k)
# Out:
# {'ndcg': 0.1902223218557026, 'recall': 0.0969647255458864}

# %% [markdown]
# ## Рекомендации по карточке

# %% [raw]
# https://www.kaggle.com/datasets/frtgnn/dunnhumby-the-complete-journey?resource=download

# %%
corpus = [
    "Молоко",
    "Хлеб",
    "Яйца",
    "Масло сливочное",
    "Масло подсолнечное",
    "Сахар",
    "Соль",
    "Мука",
    "Рис",
    "Макаронные изделия",
    "Консервированные овощи (кукуруза, горошек, фасоль)",
    "Консервированные фрукты (ананасы, персики)",
    "Кетчуп",
    "Майонез",
    "Горчица",
    "Чай",
    "Кофе",
    "Соки (апельсиновый, яблочный, мультифрукт)",
    "Газированные напитки (кола, лимонад)",
    "Минеральная вода",
    "Йогурты",
    "Сыр",
    "Колбаса",
    "Сосиски",
    "Замороженные овощи",
    "Замороженные полуфабрикаты (пельмени, котлеты)",
    "Чипсы",
    "Печенье",
    "Шоколад",
    "Конфеты",
    "Мороженое",
    "Средства для мытья посуды",
    "Стиральный порошок",
    "Мыло",
    "Шампунь",
    "Зубная паста",
    "Туалетная бумага",
    "Бумажные полотенца",
    "Влажные салфетки",
    "Кошачий корм",
    "Собачий корм",
    "Детское питание",
    "Подгузники",
    "Специи (перец, лавровый лист, корица)",
    "Орехи и сухофрукты",
    "Мед",
    "Джемы и варенье",
    "Соевый соус",
    "Оливки и маслины",
    "Снеки (орешки, сухарики)",
    "Энергетические батончики",
    "Творог",
    "Сметана",
    "Кефир",
    "Ряженка",
    "Сгущенное молоко",
    "Маргарин",
    "Крупы (гречка, овсянка, пшено)",
    "Мюсли",
    "Хлопья кукурузные",
    "Сухие завтраки",
    "Консервы рыбные (тунец, сайра, шпроты)",
    "Консервы мясные (тушенка)",
    "Паштеты",
    "Соусы (сырный, барбекю, тартар)",
    "Уксус",
    "Крахмал",
    "Разрыхлитель теста",
    "Дрожжи",
    "Ванильный сахар",
    "Какао-порошок",
    "Сгущенка вареная",
    "Мармелад",
    "Зефир",
    "Пастила",
    "Халва",
    "Семечки подсолнечные",
    "Семечки тыквенные",
    "Крекеры",
    "Гранола",
    "Сухие супы",
    "Бульонные кубики",
    "Лапша быстрого приготовления",
    "Картофельное пюре быстрого приготовления",
    "Соевое молоко",
    "Миндальное молоко",
    "Кокосовое молоко",
    "Овсяное молоко",
    "Протеиновые батончики",
    "Протеиновые коктейли",
    "Детские каши",
    "Детские пюре",
    "Детские соки",
    "Детские печенья",
    "Детские молочные смеси",
    "Детские влажные салфетки",
    "Детские шампуни",
    "Детские кремы",
    "Детские зубные пасты",
    "Детские игрушки для ванной",
    "Детские бутылочки",
    "Детские соски",
    "Детские подгузники-трусики",
    "Детские влажные салфетки с кремом",
    "Детские масла для тела",
    "Детские присыпки",
    "Детские солнцезащитные кремы",
    "Детские зубные щетки"
]

# %%
from sentence_transformers import SentenceTransformer, util
import torch
import numpy as np
from scipy.spatial.distance import cosine

embedder = SentenceTransformer('IlyaGusev/fred_t5_ru_turbo_alpaca')
# Out:
# No sentence-transformers model found with name IlyaGusev/fred_t5_ru_turbo_alpaca. Creating a new one with MEAN pooling.

# %%
embedder
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': None, 'do_lower_case': False}) with Transformer model: T5EncoderModel
#   (1): Pooling({'word_embedding_dimension': 1536, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False})
# )

# %%
# %%time

corpus_embeddings = embedder.encode(corpus, convert_to_tensor=True)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# CPU times: user 2.3 s, sys: 1.15 s, total: 3.45 s
# Wall time: 5.4 s

# %%
corpus_embeddings
# Out:
# tensor([[-0.0016, -0.0058, -0.0068,  ...,  0.0022,  0.0039,  0.0029],
#         [-0.0030, -0.0036,  0.0036,  ..., -0.0011, -0.0009, -0.0008],
#         [-0.0051,  0.0040, -0.0007,  ...,  0.0020, -0.0010,  0.0049],
#         ...,
#         [-0.0064,  0.0082,  0.0024,  ...,  0.0046, -0.0002, -0.0014],
#         [-0.0032,  0.0161,  0.0004,  ...,  0.0049,  0.0012, -0.0016],
#         [-0.0005,  0.0081, -0.0019,  ...,  0.0013, -0.0019, -0.0004]],
#        device='mps:0')

# %%
#Sentences we want to encode. Example:
queries = np.random.choice(corpus, size=50)

counts = 0
# Find the closest 5 sentences of the corpus for each query sentence based on cosine similarity
top_k = min(10, len(corpus))

for idx, query in enumerate(queries):
    query_embedding = embedder.encode(query, convert_to_tensor=True)
    # We use cosine-similarity and torch.topk to find the highest 5 scores
    # cos_scores = util.dot_score(query_embedding, corpus_embeddings)[0]
    cos_scores = util.cos_sim(query_embedding, corpus_embeddings)[0]
    top_results = torch.topk(cos_scores, k=top_k)#.numpy()
    gpt_recs = []
    for score, idx in zip(top_results[0], top_results[1]):
        #print(f'{counts+1})', corpus[idx], "(Score: {:.4f})".format(score))
        counts += 1
        gpt_recs.append(corpus[idx][:30])

    

    print("\n\n======================\n\n")
    print("Query:", query)
    print("\nTop 10 most similar sentences in corpus:")

    counts = 0
    for idx, rec in enumerate(gpt_recs):
        print(f'{counts+1})', rec)

        counts += 1
    
#     # Alternatively, we can also use util.semantic_search to perform cosine similarty + topk
#     hits = util.semantic_search(query_embedding, corpus_embeddings, top_k=5)
#     hits = hits[0]      #Get the hits for the first query
#     for hit in hits:
#         print(corpus[hit['corpus_id']], "(Score: {:.4f})".format(hit['score']))
# Out:
# ======================
#
#
# Query: Семечки подсолнечные
#
# Top 10 most similar sentences in corpus:
# 1) Семечки подсолнечные
# 2) Семечки тыквенные
# 3) Масло подсолнечное
# 4) Хлопья кукурузные
# 5) Оливки и маслины
# 6) Консервированные фрукты (анана
# 7) Снеки (орешки, сухарики)
# 8) Орехи и сухофрукты
# 9) Замороженные овощи
# 10) Консервированные овощи (кукуру
#
#
# ======================
#
#
# Query: Детские игрушки для ванной
#
# Top 10 most similar sentences in corpus:
# 1) Детские игрушки для ванной
# 2) Детские влажные салфетки
# 3) Детские зубные пасты
# 4) Детские соски
# 5) Детские печенья
# 6) Детские масла для тела
# 7) Детские зубные щетки
# 8) Детские бутылочки
# 9) Детское питание
# 10) Детские каши
#
#
# ======================
#
#
# Query: Мыло
#
# Top 10 most similar sentences in corpus:
# 1) Мыло
# 2) Ряженка
# 3) Мармелад
# 4) Молоко
# 5) Шампунь
# 6) Дрожжи
# 7) Майонез
# 8) Кетчуп
# 9) Яйца
# 10) Кефир
#
#
# ======================
#
#
# Query: Детские подгузники-трусики
#
# Top 10 most similar sentences in corpus:
# 1) Детские подгузники-трусики
# 2) Подгузники
# 3) Детские влажные салфетки с кре
# 4) Детские влажные салфетки
# 5) Детские присыпки
# 6) Детские игрушки для ванной
# 7) Детские зубные щетки
# 8) Детские солнцезащитные кремы
# 9) Детские зубные пасты
# 10) Средства для мытья посуды
#
#
# ======================
#
#
# Query: Протеиновые батончики
#
# Top 10 most similar sentences in corpus:
# 1) Протеиновые батончики
# 2) Протеиновые коктейли
# 3) Снеки (орешки, сухарики)
# 4) Замороженные полуфабрикаты (пе
# 5) Сгущенка вареная
# 6) Орехи и сухофрукты
# 7) Консервы мясные (тушенка)
# 8) Детские влажные салфетки с кре
# 9) Энергетические батончики
# 10) Газированные напитки (кола, ли
#
#
# ======================
#
#
# Query: Влажные салфетки
#
# Top 10 most similar sentences in corpus:
# 1) Влажные салфетки
# 2) Детские влажные салфетки
# 3) Детские влажные салфетки с кре
# 4) Средства для мытья посуды
# 5) Бумажные полотенца
# 6) Детские солнцезащитные кремы
# 7) Детские зубные пасты
# 8) Туалетная бумага
# 9) Зубная паста
# 10) Детские шампуни
#
#
# ======================
#
#
# Query: Конфеты
#
# Top 10 most similar sentences in corpus:
# 1) Конфеты
# 2) Паштеты
# 3) Орехи и сухофрукты
# 4) Сосиски
# 5) Замороженные овощи
# 6) Овсяное молоко
# 7) Снеки (орешки, сухарики)
# 8) Сгущенка вареная
# 9) Хлопья кукурузные
# 10) Консервированные фрукты (анана
#
#
# ======================
#
#
# Query: Уксус
#
# Top 10 most similar sentences in corpus:
# 1) Уксус
# 2) Крахмал
# 3) Яйца
# 4) Овсяное молоко
# 5) Халва
# 6) Кетчуп
# 7) Кефир
# 8) Соевое молоко
# 9) Бумажные полотенца
# 10) Чай
#
#
# ======================
#
#
# Query: Лапша быстрого приготовления
#
# Top 10 most similar sentences in corpus:
# 1) Лапша быстрого приготовления
# 2) Картофельное пюре быстрого при
# 3) Хлопья кукурузные
# 4) Сухие супы
# 5) Масло сливочное
# 6) Замороженные полуфабрикаты (пе
# 7) Сгущенка вареная
# 8) Соусы (сырный, барбекю, тартар
# 9) Бульонные кубики
# 10) Консервы мясные (тушенка)
#
#
# ======================
#
#
# Query: Мюсли
#
# Top 10 most similar sentences in corpus:
# 1) Мюсли
# 2) Соль
# 3) Яйца
# 4) Шампунь
# 5) Мороженое
# 6) Мука
# 7) Чипсы
# 8) Миндальное молоко
# 9) Детские соски
# 10) Кефир
#
#
# ======================
#
#
# Query: Энергетические батончики
#
# Top 10 most similar sentences in corpus:
# 1) Энергетические батончики
# 2) Детские соски
# 3) Сухие завтраки
# 4) Бумажные полотенца
# 5) Детские масла для тела
# 6) Детские печенья
# 7) Протеиновые батончики
# 8) Орехи и сухофрукты
# 9) Овсяное молоко
# 10) Масло сливочное
#
#
# ======================
#
#
# Query: Овсяное молоко
#
# Top 10 most similar sentences in corpus:
# 1) Овсяное молоко
# 2) Соевое молоко
# 3) Кокосовое молоко
# 4) Замороженные овощи
# 5) Хлопья кукурузные
# 6) Сгущенное молоко
# 7) Детские молочные смеси
# 8) Семечки тыквенные
# 9) Оливки и маслины
# 10) Масло сливочное
#
#
# ======================
#
#
# Query: Детские пюре
#
# Top 10 most similar sentences in corpus:
# 1) Детские пюре
# 2) Детские зубные пасты
# 3) Детское питание
# 4) Детские молочные смеси
# 5) Детские печенья
# 6) Детские игрушки для ванной
# 7) Картофельное пюре быстрого при
# 8) Сухие завтраки
# 9) Детские масла для тела
# 10) Овсяное молоко
#
#
# ======================
#
#
# Query: Сыр
#
# Top 10 most similar sentences in corpus:
# 1) Сыр
# 2) Соль
# 3) Дрожжи
# 4) Яйца
# 5) Кефир
# 6) Шампунь
# 7) Шоколад
# 8) Сосиски
# 9) Майонез
# 10) Сметана
#
#
# ======================
#
#
# Query: Бульонные кубики
#
# Top 10 most similar sentences in corpus:
# 1) Бульонные кубики
# 2) Сухие супы
# 3) Картофельное пюре быстрого при
# 4) Соусы (сырный, барбекю, тартар
# 5) Сухие завтраки
# 6) Лапша быстрого приготовления
# 7) Консервированные овощи (кукуру
# 8) Сгущенка вареная
# 9) Семечки тыквенные
# 10) Бумажные полотенца
#
#
# ======================
#
#
# Query: Мюсли
#
# Top 10 most similar sentences in corpus:
# 1) Мюсли
# 2) Соль
# 3) Яйца
# 4) Шампунь
# 5) Мороженое
# 6) Мука
# 7) Чипсы
# 8) Миндальное молоко
# 9) Детские соски
# 10) Кефир
#
#
# ======================
#
#
# Query: Детское питание
#
# Top 10 most similar sentences in corpus:
# 1) Детское питание
# 2) Детские соки
# 3) Детские зубные пасты
# 4) Детские соски
# 5) Детские игрушки для ванной
# 6) Детские печенья
# 7) Детские масла для тела
# 8) Детские бутылочки
# 9) Овсяное молоко
# 10) Соевое молоко
#
#
# ======================
#
#
# Query: Йогурты
#
# Top 10 most similar sentences in corpus:
# 1) Йогурты
# 2) Овсяное молоко
# 3) Яйца
# 4) Детские молочные смеси
# 5) Детские соки
# 6) Семечки тыквенные
# 7) Энергетические батончики
# 8) Снеки (орешки, сухарики)
# 9) Детские зубные пасты
# 10) Орехи и сухофрукты
#
#
# ======================
#
#
# Query: Детские молочные смеси
#
# Top 10 most similar sentences in corpus:
# 1) Детские молочные смеси
# 2) Детские зубные пасты
# 3) Замороженные овощи
# 4) Детские соки
# 5) Сухие завтраки
# 6) Овсяное молоко
# 7) Сухие супы
# 8) Масло сливочное
# 9) Оливки и маслины
# 10) Детские печенья
#
#
# ======================
#
#
# Query: Майонез
#
# Top 10 most similar sentences in corpus:
# 1) Майонез
# 2) Чай
# 3) Яйца
# 4) Мука
# 5) Соевое молоко
# 6) Детские соки
# 7) Крекеры
# 8) Кефир
# 9) Молоко
# 10) Детские соски
#
#
# ======================
#
#
# Query: Сосиски
#
# Top 10 most similar sentences in corpus:
# 1) Сосиски
# 2) Мороженое
# 3) Яйца
# 4) Детские соски
# 5) Конфеты
# 6) Соевое молоко
# 7) Сухие завтраки
# 8) Сгущенка вареная
# 9) Овсяное молоко
# 10) Соевый соус
#
#
# ======================
#
#
# Query: Оливки и маслины
#
# Top 10 most similar sentences in corpus:
# 1) Оливки и маслины
# 2) Орехи и сухофрукты
# 3) Консервированные фрукты (анана
# 4) Семечки тыквенные
# 5) Консервированные овощи (кукуру
# 6) Снеки (орешки, сухарики)
# 7) Замороженные овощи
# 8) Семечки подсолнечные
# 9) Соусы (сырный, барбекю, тартар
# 10) Масло сливочное
#
#
# ======================
#
#
# Query: Семечки подсолнечные
#
# Top 10 most similar sentences in corpus:
# 1) Семечки подсолнечные
# 2) Семечки тыквенные
# 3) Масло подсолнечное
# 4) Хлопья кукурузные
# 5) Оливки и маслины
# 6) Консервированные фрукты (анана
# 7) Снеки (орешки, сухарики)
# 8) Орехи и сухофрукты
# 9) Замороженные овощи
# 10) Консервированные овощи (кукуру
#
#
# ======================
#
#
# Query: Энергетические батончики
#
# Top 10 most similar sentences in corpus:
# 1) Энергетические батончики
# 2) Детские соски
# 3) Сухие завтраки
# 4) Бумажные полотенца
# 5) Детские масла для тела
# 6) Детские печенья
# 7) Протеиновые батончики
# 8) Орехи и сухофрукты
# 9) Овсяное молоко
# 10) Масло сливочное
#
#
# ======================
#
#
# Query: Джемы и варенье
#
# Top 10 most similar sentences in corpus:
# 1) Джемы и варенье
# 2) Орехи и сухофрукты
# 3) Консервированные фрукты (анана
# 4) Оливки и маслины
# 5) Консервированные овощи (кукуру
# 6) Картофельное пюре быстрого при
# 7) Сгущенка вареная
# 8) Сухие супы
# 9) Газированные напитки (кола, ли
# 10) Овсяное молоко
#
#
# ======================
#
#
# Query: Шампунь
#
# Top 10 most similar sentences in corpus:
# 1) Шампунь
# 2) Крекеры
# 3) Яйца
# 4) Миндальное молоко
# 5) Майонез
# 6) Кефир
# 7) Сметана
# 8) Кетчуп
# 9) Дрожжи
# 10) Детские соки
#
#
# ======================
#
#
# Query: Детские игрушки для ванной
#
# Top 10 most similar sentences in corpus:
# 1) Детские игрушки для ванной
# 2) Детские влажные салфетки
# 3) Детские зубные пасты
# 4) Детские соски
# 5) Детские печенья
# 6) Детские масла для тела
# 7) Детские зубные щетки
# 8) Детские бутылочки
# 9) Детское питание
# 10) Детские каши
#
#
# ======================
#
#
# Query: Рис
#
# Top 10 most similar sentences in corpus:
# 1) Рис
# 2) Мед
# 3) Дрожжи
# 4) Яйца
# 5) Молоко
# 6) Ряженка
# 7) Кетчуп
# 8) Соевое молоко
# 9) Детские соки
# 10) Крекеры
#
#
# ======================
#
#
# Query: Влажные салфетки
#
# Top 10 most similar sentences in corpus:
# 1) Влажные салфетки
# 2) Детские влажные салфетки
# 3) Детские влажные салфетки с кре
# 4) Средства для мытья посуды
# 5) Бумажные полотенца
# 6) Детские солнцезащитные кремы
# 7) Детские зубные пасты
# 8) Туалетная бумага
# 9) Зубная паста
# 10) Детские шампуни
#
#
# ======================
#
#
# Query: Мука
#
# Top 10 most similar sentences in corpus:
# 1) Мука
# 2) Чай
# 3) Кофе
# 4) Хлеб
# 5) Пастила
# 6) Соль
# 7) Майонез
# 8) Крекеры
# 9) Кефир
# 10) Яйца
#
#
# ======================
#
#
# Query: Гранола
#
# Top 10 most similar sentences in corpus:
# 1) Гранола
# 2) Халва
# 3) Маргарин
# 4) Соевое молоко
# 5) Крахмал
# 6) Кефир
# 7) Кетчуп
# 8) Овсяное молоко
# 9) Детские соки
# 10) Мука
#
#
# ======================
#
#
# Query: Майонез
#
# Top 10 most similar sentences in corpus:
# 1) Майонез
# 2) Чай
# 3) Яйца
# 4) Мука
# 5) Соевое молоко
# 6) Детские соки
# 7) Крекеры
# 8) Кефир
# 9) Молоко
# 10) Детские соски
#
#
# ======================
#
#
# Query: Влажные салфетки
#
# Top 10 most similar sentences in corpus:
# 1) Влажные салфетки
# 2) Детские влажные салфетки
# 3) Детские влажные салфетки с кре
# 4) Средства для мытья посуды
# 5) Бумажные полотенца
# 6) Детские солнцезащитные кремы
# 7) Детские зубные пасты
# 8) Туалетная бумага
# 9) Зубная паста
# 10) Детские шампуни
#
#
# ======================
#
#
# Query: Специи (перец, лавровый лист, корица)
#
# Top 10 most similar sentences in corpus:
# 1) Специи (перец, лавровый лист,
# 2) Консервированные овощи (кукуру
# 3) Соки (апельсиновый, яблочный,
# 4) Крупы (гречка, овсянка, пшено)
# 5) Орехи и сухофрукты
# 6) Консервированные фрукты (анана
# 7) Снеки (орешки, сухарики)
# 8) Соусы (сырный, барбекю, тартар
# 9) Оливки и маслины
# 10) Консервы рыбные (тунец, сайра,
#
#
# ======================
#
#
# Query: Детские игрушки для ванной
#
# Top 10 most similar sentences in corpus:
# 1) Детские игрушки для ванной
# 2) Детские влажные салфетки
# 3) Детские зубные пасты
# 4) Детские соски
# 5) Детские печенья
# 6) Детские масла для тела
# 7) Детские зубные щетки
# 8) Детские бутылочки
# 9) Детское питание
# 10) Детские каши
#
#
# ======================
#
#
# Query: Бульонные кубики
#
# Top 10 most similar sentences in corpus:
# 1) Бульонные кубики
# 2) Сухие супы
# 3) Картофельное пюре быстрого при
# 4) Соусы (сырный, барбекю, тартар
# 5) Сухие завтраки
# 6) Лапша быстрого приготовления
# 7) Консервированные овощи (кукуру
# 8) Сгущенка вареная
# 9) Семечки тыквенные
# 10) Бумажные полотенца
#
#
# ======================
#
#
# Query: Минеральная вода
#
# Top 10 most similar sentences in corpus:
# 1) Минеральная вода
# 2) Газированные напитки (кола, ли
# 3) Кошачий корм
# 4) Овсяное молоко
# 5) Детские зубные пасты
# 6) Детские молочные смеси
# 7) Сухие завтраки
# 8) Кокосовое молоко
# 9) Детские влажные салфетки
# 10) Бумажные полотенца
#
#
# ======================
#
#
# Query: Маргарин
#
# Top 10 most similar sentences in corpus:
# 1) Маргарин
# 2) Детские соки
# 3) Паштеты
# 4) Мармелад
# 5) Майонез
# 6) Соевое молоко
# 7) Ряженка
# 8) Овсяное молоко
# 9) Подгузники
# 10) Масло подсолнечное
#
#
# ======================
#
#
# Query: Подгузники
#
# Top 10 most similar sentences in corpus:
# 1) Подгузники
# 2) Детские подгузники-трусики
# 3) Детские игрушки для ванной
# 4) Детские влажные салфетки
# 5) Паштеты
# 6) Детские бутылочки
# 7) Детские зубные пасты
# 8) Бумажные полотенца
# 9) Соевое молоко
# 10) Конфеты
#
#
# ======================
#
#
# Query: Консервы мясные (тушенка)
#
# Top 10 most similar sentences in corpus:
# 1) Консервы мясные (тушенка)
# 2) Консервы рыбные (тунец, сайра,
# 3) Замороженные полуфабрикаты (пе
# 4) Консервированные овощи (кукуру
# 5) Консервированные фрукты (анана
# 6) Сгущенка вареная
# 7) Соусы (сырный, барбекю, тартар
# 8) Картофельное пюре быстрого при
# 9) Крупы (гречка, овсянка, пшено)
# 10) Снеки (орешки, сухарики)
#
#
# ======================
#
#
# Query: Кокосовое молоко
#
# Top 10 most similar sentences in corpus:
# 1) Кокосовое молоко
# 2) Овсяное молоко
# 3) Соевое молоко
# 4) Замороженные овощи
# 5) Сгущенное молоко
# 6) Масло сливочное
# 7) Детские соки
# 8) Детские молочные смеси
# 9) Масло подсолнечное
# 10) Детские зубные пасты
#
#
# ======================
#
#
# Query: Детские соски
#
# Top 10 most similar sentences in corpus:
# 1) Детские соски
# 2) Детские соки
# 3) Детские печенья
# 4) Детские игрушки для ванной
# 5) Детское питание
# 6) Детские зубные пасты
# 7) Детские масла для тела
# 8) Детские каши
# 9) Соевое молоко
# 10) Детские влажные салфетки
#
#
# ======================
#
#
# Query: Джемы и варенье
#
# Top 10 most similar sentences in corpus:
# 1) Джемы и варенье
# 2) Орехи и сухофрукты
# 3) Консервированные фрукты (анана
# 4) Оливки и маслины
# 5) Консервированные овощи (кукуру
# 6) Картофельное пюре быстрого при
# 7) Сгущенка вареная
# 8) Сухие супы
# 9) Газированные напитки (кола, ли
# 10) Овсяное молоко
#
#
# ======================
#
#
# Query: Конфеты
#
# Top 10 most similar sentences in corpus:
# 1) Конфеты
# 2) Паштеты
# 3) Орехи и сухофрукты
# 4) Сосиски
# 5) Замороженные овощи
# 6) Овсяное молоко
# 7) Снеки (орешки, сухарики)
# 8) Сгущенка вареная
# 9) Хлопья кукурузные
# 10) Консервированные фрукты (анана
#
#
# ======================
#
#
# Query: Рис
#
# Top 10 most similar sentences in corpus:
# 1) Рис
# 2) Мед
# 3) Дрожжи
# 4) Яйца
# 5) Молоко
# 6) Ряженка
# 7) Кетчуп
# 8) Соевое молоко
# 9) Детские соки
# 10) Крекеры
#
#
# ======================
#
#
# Query: Рис
#
# Top 10 most similar sentences in corpus:
# 1) Рис
# 2) Мед
# 3) Дрожжи
# 4) Яйца
# 5) Молоко
# 6) Ряженка
# 7) Кетчуп
# 8) Соевое молоко
# 9) Детские соки
# 10) Крекеры
#
#
# ======================
#
#
# Query: Подгузники
#
# Top 10 most similar sentences in corpus:
# 1) Подгузники
# 2) Детские подгузники-трусики
# 3) Детские игрушки для ванной
# 4) Детские влажные салфетки
# 5) Паштеты
# 6) Детские бутылочки
# 7) Детские зубные пасты
# 8) Бумажные полотенца
# 9) Соевое молоко
# 10) Конфеты
#
#
# ======================
#
#
# Query: Консервы мясные (тушенка)
#
# Top 10 most similar sentences in corpus:
# 1) Консервы мясные (тушенка)
# 2) Консервы рыбные (тунец, сайра,
# 3) Замороженные полуфабрикаты (пе
# 4) Консервированные овощи (кукуру
# 5) Консервированные фрукты (анана
# 6) Сгущенка вареная
# 7) Соусы (сырный, барбекю, тартар
# 8) Картофельное пюре быстрого при
# 9) Крупы (гречка, овсянка, пшено)
# 10) Снеки (орешки, сухарики)
#
#
# ======================
#
#
# Query: Чай
#
# Top 10 most similar sentences in corpus:
# 1) Чай
# 2) Мука
# 3) Хлеб
# 4) Кофе
# 5) Пастила
# 6) Майонез
# 7) Соль
# 8) Крекеры
# 9) Молоко
# 10) Дрожжи
#
#
# ======================
#
#
# Query: Детские солнцезащитные кремы
#
# Top 10 most similar sentences in corpus:
# 1) Детские солнцезащитные кремы
# 2) Детские влажные салфетки
# 3) Детские влажные салфетки с кре
# 4) Детские присыпки
# 5) Детские зубные щетки
# 6) Детские зубные пасты
# 7) Детские игрушки для ванной
# 8) Средства для мытья посуды
# 9) Детские подгузники-трусики
# 10) Влажные салфетки
